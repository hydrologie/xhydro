# %%
using Extremes

# %%
data = Extremes.dataset("wooster")
println(typeof(data))
df = copy(data)
df[!,:Temperature] = -data[:,:Temperature]
first(df, 5)
# Out:
# DataFrames.DataFrame
# 5×2 DataFrame
#  Row │ Date        Temperature
#      │ Date        Int64
# ─────┼─────────────────────────
#    1 │ 1983-01-01          -23
#    2 │ 1983-01-02          -29
#    3 │ 1983-01-03          -19
#    4 │ 1983-01-04          -14
#    5 │ 1983-01-05          -27

# %%
cluster = getcluster(df[:,:Temperature], -10.0, runlength=4)
# Out:
# 19-element Vector{Cluster}:
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [17, 18, 19, 20]
# value: [-6, -5, -6, -1]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [44]
# value: [-7]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [353, 356, 357, 358, 359, 360, 363, 364, 365]
# value: [-9, -7, -3, 13, 12, 8, 1, 4, -4]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [375, 376, 377, 378, 380, 381, 383, 384, 385, 386, 387, 388]
# value: [-6, -4, -3, -9, -1, 0, -2, 3, 9, 16, 2, -7]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [396, 397]
# value: [-7, -1]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [426, 427, 428, 429, 433, 434, 435, 436, 437]
# value: [-7, -8, -1, 2, -9, 6, 4, -7, 0]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [707]
# value: [-6]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [740]
# value: [-8]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [747, 750, 751, 752, 753, 757, 761, 764, 765, 766, 769, 770, 771, 772]
# value: [1, 5, 19, 18, -9, -7, -7, -7, 5, 13, -5, 2, 1, 3]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [777, 778]
# value: [-6, -4]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1079, 1080, 1083, 1084, 1085, 1086, 1087, 1090, 1091, 1093]
# value: [-8, -9, -1, 2, -2, -6, -6, 0, 2, -5]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1103, 1104]
# value: [-7, -3]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1109, 1111]
# value: [-8, 1]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1123, 1124]
# value: [-2, -1]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1139, 1140]
# value: [-8, -4]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1154, 1155]
# value: [-9, -6]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1162, 1163]
# value: [-4, 1]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1484, 1485, 1486, 1487, 1488]
# value: [1, 3, -1, -7, 0]
#
#  Cluster
# u₁: -10.0
# u₂: -10.0
# position: [1507, 1508, 1509]
# value: [-8, -7, -8]

# %%
u₁ = -10
u₂ = -15
cluster = getcluster(df[:,:Temperature], -10, -15)
# Out:
# 30-element Vector{Cluster}:
#  Cluster
# u₁: -10
# u₂: -15
# position: [16, 17, 18, 19, 20]
# value: [-13, -6, -5, -6, -1]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [44]
# value: [-7]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [353, 354, 355, 356, 357, 358, 359, 360, 361]
# value: [-9, -10, -12, -7, -3, 13, 12, 8, -11]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [363, 364, 365]
# value: [1, 4, -4]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [375, 376, 377, 378]
# value: [-6, -4, -3, -9]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [380, 381]
# value: [-1, 0]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [383, 384, 385, 386, 387, 388]
# value: [-2, 3, 9, 16, 2, -7]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [396, 397]
# value: [-7, -1]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [425, 426, 427, 428, 429]
# value: [-14, -7, -8, -1, 2]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [432, 433, 434, 435, 436, 437]
# value: [-14, -9, 6, 4, -7, 0]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [707]
# value: [-6]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [740]
# value: [-8]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [746, 747]
# value: [-11, 1]
#
#  ⋮
#  Cluster
# u₁: -10
# u₂: -15
# position: [1079, 1080]
# value: [-8, -9]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1082, 1083, 1084, 1085, 1086, 1087]
# value: [-12, -1, 2, -2, -6, -6]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1089, 1090, 1091]
# value: [-11, 0, 2]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1093]
# value: [-5]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1102, 1103, 1104, 1105]
# value: [-13, -7, -3, -14]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1109, 1110, 1111, 1112]
# value: [-8, -11, 1, -13]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1123, 1124, 1125]
# value: [-2, -1, -11]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1138, 1139, 1140]
# value: [-14, -8, -4]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1154, 1155, 1156]
# value: [-9, -6, -10]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1162, 1163]
# value: [-4, 1]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1484, 1485, 1486, 1487, 1488, 1489]
# value: [1, 3, -1, -7, 0, -13]
#
#  Cluster
# u₁: -10
# u₂: -15
# position: [1507, 1508, 1509]
# value: [-8, -7, -8]

# %%
y = [69, 420]
locationcov = [Variable("a", [1,2]), Variable("b", [3,1])]
logscalecov = [Variable("c", [0, 25000]), Variable("d", [0, 35000])]
shapecov = [Variable("e", [7,8]), Variable("f", [9,7])]
gevfit(y, locationcov=locationcov, logscalecov=logscalecov, shapecov=shapecov)
# Out:
# Scale must be positive
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] GeneralizedExtremeValue
#     @ C:\Users\KAMIL PC\.julia\packages\Distributions\SUTV1\src\univariate\continuous\generalizedextremevalue.jl:43 [inlined]
#   [3] GeneralizedExtremeValue
#     @ C:\Users\KAMIL PC\.julia\packages\Distributions\SUTV1\src\univariate\continuous\generalizedextremevalue.jl:48 [inlined]
#   [4] _broadcast_getindex_evalf
#     @ .\broadcast.jl:683 [inlined]
#   [5] _broadcast_getindex
#     @ .\broadcast.jl:656 [inlined]
#   [6] getindex
#     @ .\broadcast.jl:610 [inlined]
#   [7] macro expansion
#     @ .\broadcast.jl:974 [inlined]
#   [8] macro expansion
#     @ .\simdloop.jl:77 [inlined]
#   [9] copyto!
#     @ .\broadcast.jl:973 [inlined]
#  [10] copyto!
#     @ .\broadcast.jl:926 [inlined]
#  [11] copy
#     @ .\broadcast.jl:898 [inlined]
#  [12] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, Type{Distributions.GeneralizedExtremeValue}, Tuple{Vector{Float64}, Vector{Float64}, Vector{Float64}}})
#     @ Base.Broadcast .\broadcast.jl:873
#  [13] getdistribution(model::BlockMaxima{Distributions.GeneralizedExtremeValue}, θ::Vector{Float64})
#     @ Extremes C:\Users\KAMIL PC\.julia\packages\Extremes\Y6cgI\src\structures\AbstractExtremeValueModel\blockmaxima\blockmaxima{GeneralizedExtremeValue}.jl:47
#  [14] getinitialvalue(#unused#::Type{Distributions.GeneralizedExtremeValue}, y::Vector{Int64})
#     @ Extremes C:\Users\KAMIL PC\.julia\packages\Extremes\Y6cgI\src\utils.jl:21
#  [15] getinitialvalue(model::BlockMaxima{Distributions.GeneralizedExtremeValue})
#     @ Extremes C:\Users\KAMIL PC\.julia\packages\Extremes\Y6cgI\src\structures\AbstractExtremeValueModel\blockmaxima\blockmaxima{GeneralizedExtremeValue}.jl:58
#  [16] fit
#     @ C:\Users\KAMIL PC\.julia\packages\Extremes\Y6cgI\src\parameterestimation\maximumlikelihood.jl:38 [inlined]
#  [17] gevfit(y::Vector{Int64}; locationcov::Vector{Variable}, logscalecov::Vector{Variable}, shapecov::Vector{Variable})
#     @ Extremes C:\Users\KAMIL PC\.julia\packages\Extremes\Y6cgI\src\parameterestimation\maximumlikelihood\maximumlikelihood_gev.jl:58
#  [18] top-level scope
#     @ In[20]:5
