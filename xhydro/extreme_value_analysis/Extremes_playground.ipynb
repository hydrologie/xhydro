# %%
using Extremes

# %%
data = Extremes.dataset("fremantle")
first(data,5)
fm = gevfit(data, :SeaLevel)
# println(data)
fm.model

# %%
println(typeof(fm.model.location.fun))
println(typeof(fm.model.logscale.fun))
println(typeof(fm.model.shape.fun))
